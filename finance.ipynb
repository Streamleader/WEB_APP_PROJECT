# %%
pip install --user xgboost
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.preprocessing import LabelEncoder
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import mean_squared_error, r2_score
from catboost import CatBoostRegressor
import xgboost as xgb
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[10], line 12
#      10 from sklearn.metrics import mean_squared_error, r2_score
#      11 from catboost import CatBoostRegressor
# ---> 12 import xgboost as xgb
#
# ModuleNotFoundError: No module named 'xgboost'

# %%
train = pd.read_csv('Train (4).csv')
test= pd.read_csv('Test copy.csv')

# %%
test['sep'] = 1
train['sep'] = 0

data = pd.concat([test, train])

# datas = data.drop(['gender_of_respondent'], axis=1)

# %%
data
# Out:
#       country  year       uniqueid location_type cellphone_access  \
# 0       Kenya  2018  uniqueid_6056         Urban              Yes
# 1       Kenya  2018  uniqueid_6060         Urban              Yes
# 2       Kenya  2018  uniqueid_6065         Rural               No
# 3       Kenya  2018  uniqueid_6072         Rural               No
# 4       Kenya  2018  uniqueid_6073         Urban               No
# ...       ...   ...            ...           ...              ...
# 23519  Uganda  2018  uniqueid_2113         Rural              Yes
# 23520  Uganda  2018  uniqueid_2114         Rural              Yes
# 23521  Uganda  2018  uniqueid_2115         Rural              Yes
# 23522  Uganda  2018  uniqueid_2116         Urban              Yes
# 23523  Uganda  2018  uniqueid_2117         Rural              Yes
#
#        household_size  age_of_respondent gender_of_respondent  \
# 0                   3                 30                 Male
# ...

# %%
train = data[data['sep']==0]
test = data[data['sep']==1]

# %%
scaler = MinMaxScaler(feature_range=(0, 1))
data = scaler.fit_transform(data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 scaler = MinMaxScaler(feature_range=(0, 1))
#       2 data = scaler.fit_transform(data)
#
# NameError: name 'MinMaxScaler' is not defined

# %%
label_encoder = LabelEncoder()

# %%
data['location_type'], data['cellphone_access'],data['relationship_with_head'], \
    data['marital_status'],data['gender_of_respondent'], data['education_level'], data['job_type'], \
         = label_encoder.fit_transform(data['location_type']),\
label_encoder.fit_transform(data['cellphone_access']),\
label_encoder.fit_transform(data['relationship_with_head']),\
label_encoder.fit_transform(data['marital_status']),\
label_encoder.fit_transform(data['education_level']),\
label_encoder.fit_transform(data['job_type']),\
label_encoder.fit_transform(data['gender_of_respondent'])

# %%
train = data[data['sep']==0]
test = data[data['sep']==1]

# %%
train['bank_account'] = label_encoder.fit_transform(train['bank_account'])
# Out:
# /var/folders/kt/w7pxhthd1jb_m7n_v0x01k8c0000gn/T/ipykernel_7468/3266000100.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train['bank_account'] = label_encoder.fit_transform(train['bank_account'])

# %%
test['bank_account'] = label_encoder.fit_transform(test['bank_account'])
# Out:
# /var/folders/kt/w7pxhthd1jb_m7n_v0x01k8c0000gn/T/ipykernel_7468/1186975822.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['bank_account'] = label_encoder.fit_transform(test['bank_account'])

# %%
x = train[['location_type','cellphone_access','household_size','age_of_respondent','gender_of_respondent','relationship_with_head','marital_status','education_level','job_type']]
y = train['bank_account']

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.3)

# %%
model = LogisticRegression()
# model = xgb.XGBClassifier(objective='binary:logistic', eval_metric='logloss')

# %%
model.fit(x_train, y_train)
# Out:
# /Users/johannesmphaka/micromamba/envs/.azure_v2/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
model_predict = model.predict(x_test)
model_predict
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
accuracy = accuracy_score(y_test, model_predict)
conf_matrix = confusion_matrix(y_test, model_predict)
classification_rep = classification_report(y_test, model_predict)

# %%
print(f"Accuracy: {accuracy:.2f}")
print("\nConfusion Matrix:")
print(conf_matrix)
print("\nClassification Report:")
print(classification_rep)
# Out:
# Accuracy: 0.87
#
# Confusion Matrix:
# [[5953  132]
#  [ 759  214]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.89      0.98      0.93      6085
#            1       0.62      0.22      0.32       973
#
#     accuracy                           0.87      7058
#    macro avg       0.75      0.60      0.63      7058
# weighted avg       0.85      0.87      0.85      7058

# %%
model = RandomForestClassifier()

model.fit(x_train, y_train)
feature_importances = model.feature_importances_
feature_importance_df = pd.DataFrame({'Feature': x.columns, 'Importance': feature_importances})
feature_importance_df = feature_importance_df.sort_values(by='Importance', ascending=False)
print(feature_importance_df)
# Out:
#                   Feature  Importance
# 3       age_of_respondent    0.367181
# 4    gender_of_respondent    0.175039
# 2          household_size    0.152205
# 7         education_level    0.125397
# 6          marital_status    0.050814
# 5  relationship_with_head    0.039909
# 0           location_type    0.033626
# 1        cellphone_access    0.033071
# 8                job_type    0.022758

# %%
#TESTING PART

# %%
test
# Out:
#       country  year       uniqueid  location_type  cellphone_access  \
# 0       Kenya  2018  uniqueid_6056              1                 1
# 1       Kenya  2018  uniqueid_6060              1                 1
# 2       Kenya  2018  uniqueid_6065              0                 0
# 3       Kenya  2018  uniqueid_6072              0                 0
# 4       Kenya  2018  uniqueid_6073              1                 0
# ...       ...   ...            ...            ...               ...
# 10081  Uganda  2018  uniqueid_2998              0                 0
# 10082  Uganda  2018  uniqueid_2999              1                 1
# 10083  Uganda  2018  uniqueid_3000              1                 1
# 10084  Uganda  2018  uniqueid_3001              0                 1
# 10085  Uganda  2018  uniqueid_3002              1                 1
#
#        household_size  age_of_respondent  gender_of_respondent  \
# 0                   3                 30                     3
# ...

# %%
X_ready = test.drop(columns=['country','uniqueid','year','sep','bank_account'])
X_ready
# Out:
#        location_type  cellphone_access  household_size  age_of_respondent  \
# 0                  1                 1               3                 30
# 1                  1                 1               7                 51
# 2                  0                 0               3                 77
# 3                  0                 0               6                 39
# 4                  1                 0               3                 16
# ...              ...               ...             ...                ...
# 10081              0                 0               2                 62
# 10082              1                 1               8                 42
# 10083              1                 1               1                 39
# 10084              0                 1               6                 28
# 10085              1                 1               7                 16
#
#        gender_of_respondent  relationship_with_head  marital_status  \
# ...

# %%
def reprocess_test_data(test):
    x_test = reprocess_test_data(test)
    return x_test

x_test
# Out:
#        location_type  cellphone_access  household_size  age_of_respondent  \
# 6339               0                 1               5                 49
# 3358               0                 1               6                 46
# 21217              0                 1               2                 32
# 23208              0                 1               2                 26
# 23500              1                 0               6                 26
# ...              ...               ...             ...                ...
# 1378               0                 1               2                 30
# 6359               0                 1               5                 37
# 17875              0                 1               2                 29
# 15859              0                 1               3                 34
# 23388              0                 0               8                 31
#
#        gender_of_respondent  relationship_with_head  marital_status  \
# ...

# %%
y_pred = model.predict(X_ready)
y_pred
# Out:
# array([1, 1, 0, ..., 0, 0, 0])

# %%
X_ready
# Out:
#        location_type  cellphone_access  household_size  age_of_respondent  \
# 0                  1                 1               3                 30
# 1                  1                 1               7                 51
# 2                  0                 0               3                 77
# 3                  0                 0               6                 39
# 4                  1                 0               3                 16
# ...              ...               ...             ...                ...
# 10081              0                 0               2                 62
# 10082              1                 1               8                 42
# 10083              1                 1               1                 39
# 10084              0                 1               6                 28
# 10085              1                 1               7                 16
#
#        gender_of_respondent  relationship_with_head  marital_status  \
# ...

# %%
# from sklearn.metrics import confusion_matrix, accuracy_score
# from xgboost import XGBClassifier

# # fit by setting best parameters and Evaluate model
# xgb_model = XGBClassifier(min_child_weight=1, gamma=1, subsample=0.9, max_depth=6)

# xgb_model.fit(x_train, y_train)
# y_pred = xgb_model.predict(X_ready)

# %%
accuracy = accuracy_score(y_test, model_predict)
conf_matrix = confusion_matrix(y_test, model_predict)
classification_rep = classification_report(y_test, model_predict)

# %%
print(f"Accuracy: {accuracy:.2f}")
print("\nConfusion Matrix:")
print(conf_matrix)
print("\nClassification Report:")
print(classification_rep)
# Out:
# Accuracy: 0.87
#
# Confusion Matrix:
# [[5953  132]
#  [ 759  214]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.89      0.98      0.93      6085
#            1       0.62      0.22      0.32       973
#
#     accuracy                           0.87      7058
#    macro avg       0.75      0.60      0.63      7058
# weighted avg       0.85      0.87      0.85      7058

# %%
submission = pd.DataFrame({"uniqueid": test["uniqueid"] + " x " + test["country"],
                           "bank_account": y_pred})

# %%
from sklearn.metrics import mean_absolute_error

# Assuming y_true and y_pred are your actual and predicted values, respectively
mae = mean_absolute_error(y_test, model_predict)

print(f"Mean Absolute Error: {mae}")
# Out:
# Mean Absolute Error: 0.12623972796826297

# %%
submission
# Out:
#                      uniqueid  bank_account
# 0       uniqueid_6056 x Kenya             1
# 1       uniqueid_6060 x Kenya             1
# 2       uniqueid_6065 x Kenya             0
# 3       uniqueid_6072 x Kenya             0
# 4       uniqueid_6073 x Kenya             0
# ...                       ...           ...
# 10081  uniqueid_2998 x Uganda             0
# 10082  uniqueid_2999 x Uganda             0
# 10083  uniqueid_3000 x Uganda             0
# 10084  uniqueid_3001 x Uganda             0
# 10085  uniqueid_3002 x Uganda             0
#
# [10086 rows x 2 columns]

# %%
# Create submission csv file csv file
submission.to_csv('my_first_submission.csv', index = False)
